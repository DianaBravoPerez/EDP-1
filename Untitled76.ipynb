# %% [markdown]
# <a href="https://colab.research.google.com/github/DianaBravoPerez/EDP-1/blob/main/Untitled76.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy as sp

# La 't' la usamos como ayudante temporal
x, t, b, c = sp.symbols('x t b c')

#  Escribimos la fórmula f2(x)

f2 = (-2 * (t - c)) / (c - b)**2

# Hacemos la integración.

F2 = sp.integrate(f2, (t, b, x))

F2_= sp.simplify(F2)

print("ecuación:")
sp.pprint(F2_limpia)
# Out:
# ecuación:
#  2                    2
# b  - 2⋅b⋅c + 2⋅c⋅x - x
# ───────────────────────
#      2            2
#     b  - 2⋅b⋅c + c

# %% [markdown]
#  2                    2
# b  - 2⋅b⋅c + 2⋅c⋅x - x
# ───────────────────────
#      2            2
#     b  - 2⋅b⋅c + c
