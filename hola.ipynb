# %% [markdown]
# # 1.- Ecuación logıstica

# %% [markdown]
# La solución de la ecuación
# $$\frac{d p}{d t} = ap−bp^2, \;\; p(0) =p0$$
# Veamos ahora como se resuelve con SymPy

# %% [markdown]
# Primeramente importamos la libreria SymPy a Python,

# %%
>>> import sympy as sp

# %% [markdown]
# Definimos las variables independiente y dependiente ası como los parametros de forma simbolica

# %%
import sympy as sp

t = sp.symbols('t')
p=sp.Function('p')
a=sp.symbols('a')
b=sp.symbols('b')
p0=sp.symbols('p0')

# %% [markdown]
# Ahora definimos la ecuacion diferencial y la resolvemos con la condicion inicial usando dsolve

# %%
ode=sp.Eq(sp.Derivative(p(t),t)-a*p(t)+b*p(t)*p(t),0)
sol = sp.dsolve(ode,p(t),ics={p(0):p0})

# %% [markdown]
# Obteniendo ası la solucion

# %%
# Definir las variables simbólicas
t, a, b, p0 = sp.symbols('t a b p0')
p = sp.Function('p')(t)  # Definir p como función de t

# Definir la ecuación correctamente
eq = sp.Eq(
    p,
    a * sp.exp(a * (t + sp.log(b * p0 / (-a + b * p0)) / a)) /
    (b * (sp.exp(a * (t + sp.log(b * p0 / (-a + b * p0)) / a)) - 1))
)

# Mostrar la ecuación corregida
eq
# Out:
# Eq(p(t), a*exp(a*(t + log(b*p0/(-a + b*p0))/a))/(b*(exp(a*(t + log(b*p0/(-a + b*p0))/a)) - 1)))

# %% [markdown]
# Definimos a continuacion los valores de a, b y p0, y evaluamos las respectivas soluciones (una para cada condicion inicial)

# %%
constants={a:0.03,b:0.0001,p0:5}
sol1=sol.subs(constants)
constants={a:0.03,b:0.0001,p0:6}
sol2=sol.subs(constants)
constants={a:0.03,b:0.0001,p0:7}
sol3=sol.subs(constants)

# %% [markdown]
# La funcion lambdify permite definir una funcion a partir de la expresion simbolica:

# %%
func1 = sp.lambdify(t,sol1.rhs,'numpy')
func2 = sp.lambdify(t,sol2.rhs,'numpy')
func3 = sp.lambdify(t,sol3.rhs,'numpy')

# %% [markdown]
# A continuacion, importamos los modulosscipy, matplotlib y pyplotpara graficar nuestras soluciones

# %%
import numpy as np  # Importar NumPy

tt = np.arange(0, 200, 1)  # Usar np.arange() en lugar de scipy.arange()
pp1 = func1(tt)
pp2 = func2(tt)
pp3 = func3(tt)
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.plot(tt,pp1,'r',tt,pp2,'b',tt,pp3,'g')
plt.xlabel('tiempo t')
plt.ylabel('Poblacion p(t)')
plt.show()

# %% [markdown]
# 2. Ecuacion de Lagrange
#
# $$ y= 2xy'+ log(y') $$
# Para resolver con Python usamos:

# %%
from sympy import *
import sympy as sp

x=sp.symbols('x')
y=sp.Function('y')
ode2=sp.Eq(log(sp.Derivative(y(x),x))+2*x*sp.Derivative(y(x),x)-y(x),0)
sol2 = sp.dsolve(ode2,y(x))

# %%
from sympy import *
import sympy as sp

x = sp.symbols('x')
y = sp.Function('y')  # Define y as a function

# Now you can use y(x) in your equations
eq = Eq(C1 - y(x) - log(LambertW(2 * x * exp(y(x))) + 2) + LambertW(2 * x * exp(y(x))), 0)

# Display the equation
eq
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-9977d02f52cf> in <cell line: 0>()
#       6
#       7 # Now you can use y(x) in your equations
# ----> 8 eq = Eq(C1 - y(x) - log(LambertW(2 * x * exp(y(x))) + 2) + LambertW(2 * x * exp(y(x))), 0)
#       9
#      10 # Display the equation
#
# NameError: name 'C1' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir el rango de x
x = np.linspace(0.01, 10, 100)  # Evitamos x=0 para evitar división por cero

# Definir los valores de C1
C1_values = [-20, -15, -10, -5, 0, 5, 10, 15, 20]

# Crear la figura
plt.figure(figsize=(8, 6))

# Graficar para cada valor de C1
for C1 in C1_values:
    y = np.log(((4 * C1 * x + 1) ** (1/2) - 1) / (2 * x)) + (4 * C1 * x + 1) ** (1/2) - 1
    plt.plot(x, y, linewidth=2, label=f'C1={C1}')

# Configurar la gráfica
plt.legend()
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de la función para distintos valores de C1')

# Mostrar la gráfica
plt.show()
# Out:
# <ipython-input-35-4f2c0e81b62c>:15: RuntimeWarning: invalid value encountered in sqrt
#   y = np.log(((4 * C1 * x + 1) ** (1/2) - 1) / (2 * x)) + (4 * C1 * x + 1) ** (1/2) - 1
# <ipython-input-35-4f2c0e81b62c>:15: RuntimeWarning: invalid value encountered in log
#   y = np.log(((4 * C1 * x + 1) ** (1/2) - 1) / (2 * x)) + (4 * C1 * x + 1) ** (1/2) - 1
# <ipython-input-35-4f2c0e81b62c>:15: RuntimeWarning: divide by zero encountered in log
#   y = np.log(((4 * C1 * x + 1) ** (1/2) - 1) / (2 * x)) + (4 * C1 * x + 1) ** (1/2) - 1

# %% [markdown]
# 3. Resonancia
# $$y''+ 16y= 8 sen(4t),  y(0) = 1,  y'(0) = 0$$

# %% [markdown]
# Para resolver con Python:

# %%
from sympy import *
import sympy as sp
t=sp.symbols('t')
y=sp.Function('y')
ode3=sp.Eq(sp.Derivative(y(t),t,t)+16*y(t)-8*sin(4*t),0)

# %% [markdown]
# Resolvemos la ecuacion diferencia:

# %%
sol3 = sp.dsolve(ode3,y(t))

# %% [markdown]
# para obtener:

# %%
from sympy import *
import sympy as sp

t = sp.symbols('t')
y = sp.Function('y')
C1, C2 = sp.symbols('C1, C2')  # Define C1 and C2 as symbols

ode3 = sp.Eq(sp.Derivative(y(t), t, t) + 16 * y(t) - 8 * sin(4 * t), 0)
sol3 = sp.dsolve(ode3, y(t))

# Now you can use C1 and C2 in your equation
Eq(y(t), C2 * sin(4 * t) + (C1 - t) * cos(4 * t))
# Out:
# Eq(y(t), C2*sin(4*t) + (C1 - t)*cos(4*t))

# %% [markdown]
# Vamos ahora a definir las condiciones iniciales y substituirlas en la solucion:

# %%
const=sp.solve([sol3.rhs.subs(t,0)-1, sol3.rhs.diff(t,1).subs(t,0)-0])
C1, C2 = sp.symbols('C1,C2')
sol3=sol3.subs(const)

# %% [markdown]
# Definimos una funcion a partir de la solucion simbolica obtenida

# %%
func1 = sp.lambdify(t,sol3.rhs,'numpy')
import numpy as np # Import numpy
xx = np.arange(0,10,.1) # Use np.arange instead of scipy.arange
yy1 = func1(xx)

# %% [markdown]
# Y graficamos con los comandos:

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.plot(xx,yy1,'r')
plt.xlabel('tiempo t')
plt.ylabel('y(t)')
plt.show()

# %% [markdown]
# 4. Ecuacion de tercer orden
# $$y'''−y''−y'+y=g(t)$$

# %%
from sympy import *
import sympy as sp
t=sp.symbols('t')
y=sp.Function('y')
g=sp.Function('g')
ode4=sp.Eq(sp.Derivative(y(t),t,3)-sp.Derivative(y(t),t,t)-sp.Derivative(y(t),t)+y(t)-g(t),0)
sol4 = sp.dsolve(ode4,y(t))

# %% [markdown]
# Obteniendo ası la solucion

# %%
from sympy import *
import sympy as sp

t = sp.symbols('t')
y = sp.Function('y')
g = sp.Function('g')
C1, C2, C3 = sp.symbols('C1, C2, C3')  # Define C1, C2, and C3 as symbols

ode4 = sp.Eq(sp.Derivative(y(t), t, 3) - sp.Derivative(y(t), t, t) - sp.Derivative(y(t), t) + y(t) - g(t), 0)
sol4 = sp.dsolve(ode4, y(t))

# Now you can use C1, C2, and C3 in your equation
Eq(y(t), (C1 + Integral(g(t) * exp(t), t) / 4) * exp(-t) + (C2 + t * (C3 + Integral(g(t) * exp(-t), t) / 2) - Integral((2 * t + 1) * g(t) * exp(-t), t) / 4) * exp(t))
# Out:
# Eq(y(t), (C1 + Integral(g(t)*exp(t), t)/4)*exp(-t) + (C2 + t*(C3 + Integral(g(t)*exp(-t), t)/2) - Integral((2*t + 1)*g(t)*exp(-t), t)/4)*exp(t))

# %% [markdown]
# 5. Una ecuacion homogenea de Cauchy-Euler de cuarto orden
#
# $$x^4y^{(4)}(x) + 6x^3y^{(3)}(x) + 9x^2y''(x) + 3xy'(x) +y(x) = 0$$

# %%
from sympy import *
import sympy as sp
x=sp.symbols('x')
y=sp.Function('y')
ode5=sp.Eq(x**4*sp.Derivative(y(x),x,4)+6*x*x*x*sp.Derivative(y(x),x,3)+9*x**2*sp.Derivative(y(x),x,2)+3*x*sp.Derivative(y(x),x)+y(x),0)
sol5 = sp.dsolve(ode5,y(x))

# %% [markdown]
# Para obtener

# %%
from sympy import *
import sympy as sp

x = sp.symbols('x')
y = sp.Function('y')
C1, C2, C3, C4 = sp.symbols('C1, C2, C3, C4')  # Define C1, C2, C3, and C4 as symbols

# Now you can use C1, C2, C3, and C4 in your equation
Eq(y(x), C3 * sin(log(x)) + C4 * cos(log(x)) + (C1 * sin(log(x)) + C2 * cos(log(x))) * log(x))
# Out:
# Eq(y(x), C3*sin(log(x)) + C4*cos(log(x)) + (C1*sin(log(x)) + C2*cos(log(x)))*log(x))

# %% [markdown]
# La literatura nos dice que un metodo de solucion de las ecuaciones de Cauchy Euler implica la substitucion $$ y=x^n$$ En Python podemos usar:

# %%
n=sp.symbols('n')
eq=simplify(ode5.subs(y(x),x**n))
factor(eq)
# Out:
# Eq(x**n*(n**2 + 1)**2, 0)

# %% [markdown]
# 6. Un problema de valor inicial con deltas de Dirac como fuentes
# $$y′′(t)−4y′(t) + 4y(t) = 3δ(t−1) +δ(t−2),  y(0) = 1,  y′(0) = 1$$

# %%
from sympy import *
import sympy as sp
t=sp.symbols('t')
y=sp.Function('y')
ode6=sp.Eq(sp.Derivative(y(t),t,2)-4*sp.Derivative(y(t),t)+4*y(t),3*DiracDelta(t-1)+DiracDelta(t-2))
sol6 = sp.dsolve(ode6)
constants=solve([sol6.rhs.subs(t,0)-1,sol6.rhs.diff(t,1).subs(t,0)-1])
sol6.subs(constants)
# Out:
# Eq(y(t), (t*(exp(-4)*Heaviside(t - 2) + 3*exp(-2)*Heaviside(t - 1) - 1) - 2*exp(-4)*Heaviside(t - 2) - 3*exp(-2)*Heaviside(t - 1) + 1)*exp(2*t))

# %% [markdown]
# y obtenemos

# %%
Eq(y(t), (t*(exp(-4)*Heaviside(t-2)+3*exp(-2)*Heaviside(t-1)-1)-2*exp(-4)*Heaviside(t-2) - 3*exp(-2)*Heaviside(t-1)+1)*exp(2*t))
# Out:
# Eq(y(t), (t*(exp(-4)*Heaviside(t - 2) + 3*exp(-2)*Heaviside(t - 1) - 1) - 2*exp(-4)*Heaviside(t - 2) - 3*exp(-2)*Heaviside(t - 1) + 1)*exp(2*t))

# %% [markdown]
# 7. Sistema masa-resorte:
# $$mx′′(t) +ke−αtx(t) = 0$$
# La ecuacion anterior modela un resorte envejecido donde la constante decae con el tiempo, en python usamos:

# %%
from sympy import *
import sympy as sp
t=sp.symbols('t')
y=sp.Function('y')
m=sp.symbols('m')
k=sp.symbols('k')
a=sp.symbols('a')
ode7=sp.Eq(m*sp.Derivative(y(t),t,t)+k*sp.exp(-a*t)*y(t),0)
sol7 = sp.dsolve(ode7,y(t)) # Changed sympy to sp
k=sp.symbols('k')
a=sp.symbols('a')
ode7=sp.Eq(m*sp.Derivative(y(t),t,t)+k*sp.exp(-a*t)*y(t),0)
sol7 = sp.dsolve(ode7,y(t)) # Changed sympy to sp

# %% [markdown]
# para obtener la ecuacion:

# %%
from sympy import *
import sympy as sp

t = sp.symbols('t')
y = sp.Function('y')
m = sp.symbols('m')
k = sp.symbols('k')
a = sp.symbols('a')
C1, C2 = sp.symbols('C1, C2')  # Define C1 and C2 as symbols

ode7 = sp.Eq(m * sp.Derivative(y(t), t, t) + k * sp.exp(-a * t) * y(t), 0)
sol7 = sp.dsolve(ode7, y(t))  # Changed sympy to sp

# Now you can use C1 and C2 in your equation
Eq(y(t), C2 * (k ** 2 * t ** 4 * exp(-2 * a * t) / (24 * m ** 2) - k * t ** 2 * exp(-a * t) / (2 * m) + 1) + C1 * t * (-k * t ** 2 * exp(-a * t) / (6 * m) + 1) + O(t ** 6))
# Out:
# Eq(y(t), C2*(k**2*t**4*exp(-2*a*t)/(24*m**2) - k*t**2*exp(-a*t)/(2*m) + 1) + C1*t*(-k*t**2*exp(-a*t)/(6*m) + 1) + O(t**6))

# %% [markdown]
# 9. Ecuacion de Airy:
# $$y''(t)−ty(t) = 0$$
# En python usamos:

# %%
from sympy import *
import sympy as sp

t = sp.symbols('t')
y=sp.Function('y')
ode9=sp.Eq(sp.Derivative(y(t),t,t)-t*y(t),0)
sol9=dsolve(ode9,y(t))

# %% [markdown]
# Obtenemos ası una solucion que incluye funciones de Airy

# %%
Eq(y(t), C1*airyai(t) + C2*airybi(t))
# Out:
# Eq(y(t), C1*airyai(t) + C2*airybi(t))

# %% [markdown]
# vamos ahora a hallar una solucion en series de potencias centradas en cero

# %%
sols9 = sp.dsolve(ode9,hint='2nd_power_series_ordinary')
constants=solve([sols9.rhs.subs(t,0)-1,sols9.rhs.diff(t,1).subs(t,0)-1])
ysol=expand(sols9.rhs.subs(constants))

# %% [markdown]
# Y ası obtenemos:

# %%
1 + t + t**3/6 + t**4/12 + O(t**6)
# Out:
# 1 + t + t**3/6 + t**4/12 + O(t**6)

# %% [markdown]
# calculemos ahora una solucion en series de potencias centradas ent= 1:

# %%
s9=simplify(series(sol9.rhs,t,1))
constants=solve([s9.subs(t,1)-1,s9.diff(t,1).subs(t,1)-1])
ss9=s9.subs(constants)
simplify(series(ss9,t,1,6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e3c0b8ed039e> in <cell line: 0>()
# ----> 1 s9=simplify(series(sol9.rhs,t,1))
#       2 constants=solve([s9.subs(t,1)-1,s9.diff(t,1).subs(t,1)-1])
#       3 ss9=s9.subs(constants)
#       4 simplify(series(ss9,t,1,6))
#
# NameError: name 'simplify' is not defined

# %% [markdown]
# Para obtener:

# %%
(t-1)**2/2+(t-1)**3/3+(t-1)**4/8 +(t-1)**5/24 +t*airyaiprime(1)*airybi(1)/(airyaiprime(1)*airybi(1)-airyai(1)*airybiprime(1)) -t*airyai(1)*airybiprime(1)/(airyaiprime(1)*airybi(1) - airyai(1)*airybiprime(1)) + O((t-1)**6, (t,1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-cf42ac3a123d> in <cell line: 0>()
# ----> 1 (t-1)**2/2+(t-1)**3/3+(t-1)**4/8 +(t-1)**5/24 +t*airyaiprime(1)*airybi(1)/(airyaiprime(1)*airybi(1)-airyai(1)*airybiprime(1)) -t*airyai(1)*airybiprime(1)/(airyaiprime(1)*airybi(1) - airyai(1)*airybiprime(1)) + O((t-1)**6, ([0...
#
# NameError: name 't' is not defined

# %% [markdown]
# 10. Campo de direcciones de una ecuaci ́on diferencial:
# $$x′(t) =e^{−t}−2x(t)$$

# %%
import numpy as np
import matplotlib as mpl
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
x,y = np.meshgrid(np.linspace(-2,3,15),np.linspace(-2,3,15))
plt.quiver(x,y,x,np.exp(-x)-2*y)
plt.grid('on')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
plt.show()

# %% [markdown]
# **RESOLVER CON SYMPY**
#
# $$ X"- \lambda X=0, X(0)=X(1)=0 $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definimos el dominio de x
x_values = np.linspace(0, 1, 100)

# Graficamos las soluciones para n = 1, 2, 3
plt.figure(figsize=(8, 6))

for n in range(1, 4):
    # Solución X_n(x) = sin(n * pi * x)
    X_n = np.sin(n * np.pi * x_values)
    plt.plot(x_values, X_n, label=f'n = {n}')

    # Aseguramos que X(0) = 0 y X(1) = 0 para cada solución
    plt.scatter(0, 0, color='red', zorder=5)  # Marca en X(0) = 0
    plt.scatter(1, 0, color='blue', zorder=5)  # Marca en X(1) = 0

# gráfica
plt.title("Soluciones de la ecuación diferencial $X'' - \lambda X = 0$")
plt.xlabel("x")
plt.ylabel("X(x)")
plt.legend()
plt.grid(True)

# Mostramos la gráfica
plt.show()

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Definir variables
x = sp.symbols('x')

# Primeras 3 soluciones (n = 1, 2, 3)
n_values = [1, 2, 3]

# Imprimir las soluciones
print("Soluciones particulares de la ecuación diferencial:")
for n in n_values:
    X_sol = sp.sin(n * sp.pi * x)
    print(f"Solución para n = {n}: X_n(x) = sin({n} * pi * x)")

# Graficar las soluciones
x_vals = np.linspace(0, 1, 1000)

plt.figure(figsize=(8, 6))
for n in n_values:
    X_func = sp.sin(n * sp.pi * x)
    X_lambdified = sp.lambdify(x, X_func, 'numpy')
    plt.plot(x_vals, X_lambdified(x_vals), label=f'n = {n}')
plt.title('Soluciones de la ecuación diferencial')
Eq(y(t), t+1)
plt.title('Soluciones de la ecuación diferencial')
plt.xlabel('x')
plt.ylabel('X(x)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Soluciones particulares de la ecuación diferencial:
# Solución para n = 1: X_n(x) = sin(1 * pi * x)
# Solución para n = 2: X_n(x) = sin(2 * pi * x)
# Solución para n = 3: X_n(x) = sin(3 * pi * x)

# %% [markdown]
# **RESOLVER CON SYMPY**
#
# $$ X"- \lambda X=0, X´(0)=X´(1)=0 $$

# %%
#

import sympy as sp
from sympy import Eq, symbols, Function, Derivative, dsolve, lambdify, sin, cos, pi
import numpy as np
import matplotlib.pyplot as plt

#
x, lamda = symbols('x lamda')
X = Function('X')(x)

# definir la ec dif
ode = Eq(Derivative(X, x, 2) - lamda * X, 0)


general_solution = dsolve(ode, X)
print("Solucion general:")
print(general_solution)


n_values = [1,2,3] # para n
print("\nSoluciones con condiciones de frontera:")
for n in n_values:
    solution = sin(n*pi*x)
    print(f"Para n = {n}: X(x) = {solution}")

#
x_vals = np.linspace(0,1,100)
plt.figure(figsize=(8,6))
for n in n_values:
    X_func = lambdify(x, sin(n*pi*x),'numpy')
    plt.plot(x_vals, X_func(x_vals), label=f'n = {n}')

plt.title('Soluciones de la ecuación diferencial con condiciones de frontera')
plt.xlabel('x')
plt.ylabel('X(x)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Solucion general:
# Eq(X(x), C1*exp(-sqrt(lamda)*x) + C2*exp(sqrt(lamda)*x))
#
# Soluciones con condiciones de frontera:
# Para n = 1: X(x) = sin(pi*x)
# Para n = 2: X(x) = sin(2*pi*x)
# Para n = 3: X(x) = sin(3*pi*x)

# %% [markdown]
# **RESOLVER CON SYMPY** $$ X"- \lambda X=0, x´(0)=X´(1)$$

# %%
import sympy as sp
from sympy import Eq, symbols, Function, Derivative, dsolve, lambdify, sin, cos, pi
import numpy as np
import matplotlib.pyplot as plt

# Definir variables simbólicas
x, lamda = symbols('x lamda')
X = Function('X')(x)

# Definir la ecuación diferencial
ode = Eq(Derivative(X, x, 2) - lamda * X, 0)

# Resolver la ecuación diferencial
general_solution = dsolve(ode, X)
print("Solución general:")
print(general_solution)

#Soluciones:
print("\nSoluciones con condiciones de frontera X'(0) = X'(1):")
n_values = [1, 2, 3] # primeros 3 valores de n
for n in n_values:
    lambda_n = -(n * sp.pi)**2
    solution = cos(n * sp.pi * x)
    print(f"Para n = {n}, lambda = {lambda_n}: X(x) = {solution}")

# Graficar las soluciones
x_vals = np.linspace(0, 1, 100)
plt.figure(figsize=(8, 6))
for n in n_values:
    X_func = lambdify(x, cos(n * sp.pi * x), 'numpy')
    plt.plot(x_vals, X_func(x_vals), label=f'n = {n}')

plt.title('Soluciones de la ecuación diferencial con condiciones de frontera')
plt.xlabel('x')
plt.ylabel('X(x)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Solución general:
# Eq(X(x), C1*exp(-sqrt(lamda)*x) + C2*exp(sqrt(lamda)*x))
#
# Soluciones con condiciones de frontera X'(0) = X'(1):
# Para n = 1, lambda = -pi**2: X(x) = cos(pi*x)
# Para n = 2, lambda = -4*pi**2: X(x) = cos(2*pi*x)
# Para n = 3, lambda = -9*pi**2: X(x) = cos(3*pi*x)
